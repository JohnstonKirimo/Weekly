# %% [markdown]
# **Table of Contents**
#
# 1. Load data
# 2. Data Cleaning

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bike_data = pd.read_csv('/users/johnstonkirimo/projects/weekly_analysis/week1/data/bikes.csv')

# %%
bike_data.head(3)
# Out:
#   Date;Berri 1;Br?beuf (donn?es non disponibles);C?te-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (donn?es non disponibles)
# 0                   01/01/2012;35;;0;38;51;26;10;16;
# 1                   02/01/2012;83;;1;68;153;53;6;43;
# 2                 03/01/2012;135;;2;104;248;89;3;58;

# %%
#Cleaning the messy data

clean_df = pd.read_csv('/users/johnstonkirimo/projects/weekly_analysis/week1/data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
clean_df.head(3)
# Out:
#             Berri 1  Br?beuf (donn?es non disponibles)  C?te-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-01-02       83                                NaN                      1
# 2012-01-03      135                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 2012-01-01             38             51       26            10       16
# 2012-01-02             68            153       53             6       43
# 2012-01-03            104            248       89             3       58
#
#             St-Urbain (donn?es non disponibles)
# Date
# 2012-01-01                                  NaN
# 2012-01-02                                  NaN
# 2012-01-03                                  NaN

# %%
#check the months column in detail

clean_df['Berri 1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
#               ...
# 2012-11-01    2405
# 2012-11-02    1582
# 2012-11-03     844
# 2012-11-04     966
# 2012-11-05    2247
# Name: Berri 1, Length: 310, dtype: int64

# %%
#Plotting the biking volume by month

vol_by_month = clean_df['Berri 1'].plot(figsize = [15,5])

# %%
#Plotting the biking volume for each month by the paths

all_months = clean_df.plot(figsize=(15,5))
